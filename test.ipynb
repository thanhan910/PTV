# %%
import zipfile
from sqlalchemy import create_engine, types
import os
import pandas as pd
import concurrent.futures
import time
import psycopg2

# %%
# PostgreSQL connection parameters
# Database connection details
db_user = "postgres"
db_password = "postgres"
db_host = "localhost"
db_port = 5432
db_name = "gtfs"  # Replace with the actual database name

# Create the database URL
db_url = f"postgresql://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}"

# Create an SQLAlchemy engine to connect to the database
engine = create_engine(db_url)

# %%
class TablePattern:
    def __init__(self, table_name = None, version_id = None, branch_id = None, file_name : str = None) -> None:
        if file_name is None:
            self.file_name = f"{table_name}-{version_id}-{branch_id}"
        else:
            self.file_name = file_name
            file_name_split = file_name.split('-')
            self.table_name = file_name_split[0]
            self.version_id = file_name_split[1]
            self.branch_id = file_name_split[2]

# %%
dfs = []

# Extract data from the nested ZIP files
for dirpath, dirnames, filenames in os.walk('downloads'):
    for filename in filenames:
        gtfs_zip_path = os.path.join(dirpath, filename)
        version_id = gtfs_zip_path.split(os.sep)[-2]
        
        with zipfile.ZipFile(gtfs_zip_path, 'r') as gtfs_zip:
            for item in gtfs_zip.namelist():
                if item.endswith('/'): # Check if the item is a directory
                    branch_id = item.strip('/')
                    google_transit_zip_path = f"{branch_id}/google_transit.zip"
                    with gtfs_zip.open(google_transit_zip_path) as google_transit_file:
                        with zipfile.ZipFile(google_transit_file, 'r') as transit_zip:
                            nested_file_list = transit_zip.namelist()
                            for nested_file_name in nested_file_list:
                                if nested_file_name.endswith('.txt'):

                                    table_name = nested_file_name.removesuffix('.txt')
                                    print(version_id, branch_id, table_name)

                                    with transit_zip.open(nested_file_name) as nested_file:

                                        dfx = pd.read_csv(nested_file, keep_default_na=False, low_memory=False)
                                        obj = TablePattern(table_name = table_name, version_id = version_id, branch_id = branch_id)

                                        dfx.to_csv(f"output/{obj.file_name}.csv", index=False)
                                        dfs.append({
                                            'table_name': table_name,
                                            'version_id': version_id,
                                            'branch_id': branch_id,
                                            'length': len(dfx),
                                            'df': dfx
                                        })

                    
                    print(branch_id)
        print(version_id)
# 14m 45s
# Out:
# 20220403_025040 1 agency
# 20220403_025040 1 routes
# 20220403_025040 1 trips
# 20220403_025040 1 stops
# 20220403_025040 1 calendar
# 20220403_025040 1 calendar_dates
# 20220403_025040 1 shapes
# 20220403_025040 1 stop_times
# 1
# 20220403_025040 10 agency
# 20220403_025040 10 routes
# 20220403_025040 10 trips
# 20220403_025040 10 stops
# 20220403_025040 10 calendar
# 20220403_025040 10 calendar_dates
# 20220403_025040 10 shapes
# 20220403_025040 10 stop_times
# 10
# 20220403_025040 11 agency
# 20220403_025040 11 routes
# 20220403_025040 11 trips
# 20220403_025040 11 stops
# 20220403_025040 11 calendar
# 20220403_025040 11 calendar_dates
# 20220403_025040 11 shapes
# 20220403_025040 11 stop_times
# 11
# 20220403_025040 2 agency
# 20220403_025040 2 routes
# 20220403_025040 2 trips
# 20220403_025040 2 stops
# 20220403_025040 2 calendar
# 20220403_025040 2 calendar_dates
# 20220403_025040 2 shapes
# 20220403_025040 2 stop_times
# 2
# 20220403_025040 3 agency
# 20220403_025040 3 routes
# 20220403_025040 3 trips
# 20220403_025040 3 stops
# 20220403_025040 3 calendar
# 20220403_025040 3 calendar_dates
# 20220403_025040 3 shapes
# 20220403_025040 3 stop_times
# 3
# 20220403_025040 4 agency
# 20220403_025040 4 routes
# 20220403_025040 4 trips
# 20220403_025040 4 stops
# 20220403_025040 4 calendar
# 20220403_025040 4 calendar_dates
# 20220403_025040 4 shapes
# 20220403_025040 4 stop_times
# 4
# 20220403_025040 5 agency
# 20220403_025040 5 routes
# 20220403_025040 5 trips
# 20220403_025040 5 stops
# 20220403_025040 5 calendar
# 20220403_025040 5 calendar_dates
# 20220403_025040 5 shapes
# 20220403_025040 5 stop_times
# 5
# 20220403_025040 6 agency
# 20220403_025040 6 routes
# 20220403_025040 6 trips
# 20220403_025040 6 stops
# 20220403_025040 6 calendar
# 20220403_025040 6 calendar_dates
# 20220403_025040 6 shapes
# 20220403_025040 6 stop_times
# 6
# 20220403_025040 7 agency
# 20220403_025040 7 calendar
# 20220403_025040 7 calendar_dates
# 20220403_025040 7 routes
# 20220403_025040 7 shapes
# 20220403_025040 7 stops
# 20220403_025040 7 stop_times
# 20220403_025040 7 trips
# 7
# 20220403_025040 8 agency
# 20220403_025040 8 calendar
# 20220403_025040 8 calendar_dates
# 20220403_025040 8 routes
# 20220403_025040 8 shapes
# 20220403_025040 8 stops
# 20220403_025040 8 stop_times
# 20220403_025040 8 trips
# 8
# 20220403_025040
# 20220704_003721 1 agency
# 20220704_003721 1 routes
# 20220704_003721 1 trips
# 20220704_003721 1 stops
# 20220704_003721 1 calendar
# 20220704_003721 1 calendar_dates
# 20220704_003721 1 shapes
# 20220704_003721 1 stop_times
# 1
# 20220704_003721 10 agency
# 20220704_003721 10 routes
# 20220704_003721 10 trips
# 20220704_003721 10 stops
# 20220704_003721 10 calendar
# 20220704_003721 10 calendar_dates
# 20220704_003721 10 shapes
# 20220704_003721 10 stop_times
# 10
# 20220704_003721 11 agency
# 20220704_003721 11 routes
# 20220704_003721 11 trips
# 20220704_003721 11 stops
# 20220704_003721 11 calendar
# 20220704_003721 11 calendar_dates
# 20220704_003721 11 shapes
# 20220704_003721 11 stop_times
# 11
# 20220704_003721 2 agency
# 20220704_003721 2 routes
# 20220704_003721 2 trips
# 20220704_003721 2 stops
# 20220704_003721 2 calendar
# 20220704_003721 2 calendar_dates
# 20220704_003721 2 shapes
# 20220704_003721 2 stop_times
# 2
# 20220704_003721 3 agency
# 20220704_003721 3 routes
# 20220704_003721 3 trips
# 20220704_003721 3 stops
# 20220704_003721 3 calendar
# 20220704_003721 3 calendar_dates
# 20220704_003721 3 shapes
# 20220704_003721 3 stop_times
# 3
# 20220704_003721 4 agency
# 20220704_003721 4 routes
# 20220704_003721 4 trips
# 20220704_003721 4 stops
# 20220704_003721 4 calendar
# 20220704_003721 4 calendar_dates
# 20220704_003721 4 shapes
# 20220704_003721 4 stop_times
# 4
# 20220704_003721 5 agency
# 20220704_003721 5 routes
# 20220704_003721 5 trips
# 20220704_003721 5 stops
# 20220704_003721 5 calendar
# 20220704_003721 5 calendar_dates
# 20220704_003721 5 shapes
# 20220704_003721 5 stop_times
# 5
# 20220704_003721 6 agency
# 20220704_003721 6 routes
# 20220704_003721 6 trips
# 20220704_003721 6 stops
# 20220704_003721 6 calendar
# 20220704_003721 6 calendar_dates
# 20220704_003721 6 shapes
# 20220704_003721 6 stop_times
# 6
# 20220704_003721 7 agency
# 20220704_003721 7 calendar
# 20220704_003721 7 calendar_dates
# 20220704_003721 7 routes
# 20220704_003721 7 shapes
# 20220704_003721 7 stops
# 20220704_003721 7 stop_times
# 20220704_003721 7 trips
# 7
# 20220704_003721 8 agency
# 20220704_003721 8 calendar
# 20220704_003721 8 calendar_dates
# 20220704_003721 8 routes
# 20220704_003721 8 shapes
# 20220704_003721 8 stops
# 20220704_003721 8 stop_times
# 20220704_003721 8 trips
# 8
# 20220704_003721
# 20220715_191941 1 agency
# 20220715_191941 1 routes
# 20220715_191941 1 trips
# 20220715_191941 1 stops
# 20220715_191941 1 calendar
# 20220715_191941 1 calendar_dates
# 20220715_191941 1 shapes
# 20220715_191941 1 stop_times
# 1
# 20220715_191941 10 agency
# 20220715_191941 10 routes
# 20220715_191941 10 trips
# 20220715_191941 10 stops
# 20220715_191941 10 calendar
# 20220715_191941 10 calendar_dates
# 20220715_191941 10 shapes
# 20220715_191941 10 stop_times
# 10
# 20220715_191941 11 agency
# 20220715_191941 11 routes
# 20220715_191941 11 trips
# 20220715_191941 11 stops
# 20220715_191941 11 calendar
# 20220715_191941 11 calendar_dates
# 20220715_191941 11 shapes
# 20220715_191941 11 stop_times
# 11
# 20220715_191941 2 agency
# 20220715_191941 2 routes
# 20220715_191941 2 trips
# 20220715_191941 2 stops
# 20220715_191941 2 calendar
# 20220715_191941 2 calendar_dates
# 20220715_191941 2 shapes
# 20220715_191941 2 stop_times
# 2
# 20220715_191941 3 agency
# 20220715_191941 3 routes
# 20220715_191941 3 trips
# 20220715_191941 3 stops
# 20220715_191941 3 calendar
# 20220715_191941 3 calendar_dates
# 20220715_191941 3 shapes
# 20220715_191941 3 stop_times
# 3
# 20220715_191941 4 agency
# 20220715_191941 4 routes
# 20220715_191941 4 trips
# 20220715_191941 4 stops
# 20220715_191941 4 calendar
# 20220715_191941 4 calendar_dates
# 20220715_191941 4 shapes
# 20220715_191941 4 stop_times
# 4
# 20220715_191941 5 agency
# 20220715_191941 5 routes
# 20220715_191941 5 trips
# 20220715_191941 5 stops
# 20220715_191941 5 calendar
# 20220715_191941 5 calendar_dates
# 20220715_191941 5 shapes
# 20220715_191941 5 stop_times
# 5
# 20220715_191941 6 agency
# 20220715_191941 6 routes
# 20220715_191941 6 trips
# 20220715_191941 6 stops
# 20220715_191941 6 calendar
# 20220715_191941 6 calendar_dates
# 20220715_191941 6 shapes
# 20220715_191941 6 stop_times
# 6
# 20220715_191941 7 agency
# 20220715_191941 7 calendar
# 20220715_191941 7 calendar_dates
# 20220715_191941 7 routes
# 20220715_191941 7 shapes
# 20220715_191941 7 stops
# 20220715_191941 7 stop_times
# 20220715_191941 7 trips
# 7
# 20220715_191941 8 agency
# 20220715_191941 8 calendar
# 20220715_191941 8 calendar_dates
# 20220715_191941 8 routes
# 20220715_191941 8 shapes
# 20220715_191941 8 stops
# 20220715_191941 8 stop_times
# 20220715_191941 8 trips
# 8
# 20220715_191941
# 20230805_030129 1 agency
# 20230805_030129 1 calendar
# 20230805_030129 1 calendar_dates
# 20230805_030129 1 routes
# 20230805_030129 1 shapes
# 20230805_030129 1 stops
# 20230805_030129 1 stop_times
# 20230805_030129 1 trips
# 1
# 20230805_030129 10 agency
# 20230805_030129 10 calendar
# 20230805_030129 10 calendar_dates
# 20230805_030129 10 routes
# 20230805_030129 10 shapes
# 20230805_030129 10 stops
# 20230805_030129 10 stop_times
# 20230805_030129 10 trips
# 10
# 20230805_030129 11 agency
# 20230805_030129 11 calendar
# 20230805_030129 11 calendar_dates
# 20230805_030129 11 routes
# 20230805_030129 11 shapes
# 20230805_030129 11 stops
# 20230805_030129 11 stop_times
# 20230805_030129 11 trips
# 11
# 20230805_030129 2 agency
# 20230805_030129 2 calendar
# 20230805_030129 2 calendar_dates
# 20230805_030129 2 routes
# 20230805_030129 2 shapes
# 20230805_030129 2 stops
# 20230805_030129 2 stop_times
# 20230805_030129 2 trips
# 2
# 20230805_030129 3 agency
# 20230805_030129 3 calendar
# 20230805_030129 3 calendar_dates
# 20230805_030129 3 routes
# 20230805_030129 3 shapes
# 20230805_030129 3 stops
# 20230805_030129 3 stop_times
# 20230805_030129 3 trips
# 3
# 20230805_030129 4 agency
# 20230805_030129 4 routes
# 20230805_030129 4 trips
# 20230805_030129 4 stops
# 20230805_030129 4 calendar
# 20230805_030129 4 calendar_dates
# 20230805_030129 4 shapes
# 20230805_030129 4 stop_times
# 4
# 20230805_030129 5 agency
# 20230805_030129 5 calendar
# 20230805_030129 5 calendar_dates
# 20230805_030129 5 routes
# 20230805_030129 5 shapes
# 20230805_030129 5 stops
# 20230805_030129 5 stop_times
# 20230805_030129 5 trips
# 5
# 20230805_030129 6 agency
# 20230805_030129 6 calendar
# 20230805_030129 6 calendar_dates
# 20230805_030129 6 routes
# 20230805_030129 6 shapes
# 20230805_030129 6 stops
# 20230805_030129 6 stop_times
# 20230805_030129 6 trips
# 6
# 20230805_030129 7 agency
# 20230805_030129 7 routes
# 20230805_030129 7 trips
# 20230805_030129 7 stops
# 20230805_030129 7 calendar
# 20230805_030129 7 calendar_dates
# 20230805_030129 7 shapes
# 20230805_030129 7 stop_times
# 7
# 20230805_030129 8 agency
# 20230805_030129 8 routes
# 20230805_030129 8 trips
# 20230805_030129 8 stops
# 20230805_030129 8 calendar
# 20230805_030129 8 calendar_dates
# 20230805_030129 8 shapes
# 20230805_030129 8 stop_times
# 8
# 20230805_030129
# 20231021_105623 1 agency
# 20231021_105623 1 calendar
# 20231021_105623 1 calendar_dates
# 20231021_105623 1 routes
# 20231021_105623 1 shapes
# 20231021_105623 1 stops
# 20231021_105623 1 stop_times
# 20231021_105623 1 trips
# 1
# 20231021_105623 10 agency
# 20231021_105623 10 calendar
# 20231021_105623 10 calendar_dates
# 20231021_105623 10 routes
# 20231021_105623 10 shapes
# 20231021_105623 10 stops
# 20231021_105623 10 stop_times
# 20231021_105623 10 trips
# 10
# 20231021_105623 11 agency
# 20231021_105623 11 calendar
# 20231021_105623 11 calendar_dates
# 20231021_105623 11 routes
# 20231021_105623 11 shapes
# 20231021_105623 11 stops
# 20231021_105623 11 stop_times
# 20231021_105623 11 trips
# 11
# 20231021_105623 2 agency
# 20231021_105623 2 calendar
# 20231021_105623 2 calendar_dates
# 20231021_105623 2 routes
# 20231021_105623 2 shapes
# 20231021_105623 2 stops
# 20231021_105623 2 stop_times
# 20231021_105623 2 trips
# 2
# 20231021_105623 3 agency
# 20231021_105623 3 calendar
# 20231021_105623 3 calendar_dates
# 20231021_105623 3 routes
# 20231021_105623 3 shapes
# 20231021_105623 3 stops
# 20231021_105623 3 stop_times
# 20231021_105623 3 trips
# 3
# 20231021_105623 4 agency
# 20231021_105623 4 calendar
# 20231021_105623 4 calendar_dates
# 20231021_105623 4 routes
# 20231021_105623 4 shapes
# 20231021_105623 4 stops
# 20231021_105623 4 stop_times
# 20231021_105623 4 trips
# 4
# 20231021_105623 5 agency
# 20231021_105623 5 calendar
# 20231021_105623 5 calendar_dates
# 20231021_105623 5 routes
# 20231021_105623 5 shapes
# 20231021_105623 5 stops
# 20231021_105623 5 stop_times
# 20231021_105623 5 trips
# 5
# 20231021_105623 6 agency
# 20231021_105623 6 calendar
# 20231021_105623 6 calendar_dates
# 20231021_105623 6 routes
# 20231021_105623 6 shapes
# 20231021_105623 6 stops
# 20231021_105623 6 stop_times
# 20231021_105623 6 trips
# 6
# 20231021_105623 7 agency
# 20231021_105623 7 routes
# 20231021_105623 7 trips
# 20231021_105623 7 stops
# 20231021_105623 7 calendar
# 20231021_105623 7 calendar_dates
# 20231021_105623 7 shapes
# 20231021_105623 7 stop_times
# 7
# 20231021_105623 8 agency
# 20231021_105623 8 routes
# 20231021_105623 8 trips
# 20231021_105623 8 stops
# 20231021_105623 8 calendar
# 20231021_105623 8 calendar_dates
# 20231021_105623 8 shapes
# 20231021_105623 8 stop_times
# 8
# 20231021_105623

# %%
# for csv files in oiutput folder
dfs = []
for dirpath, dirnames, filenames in os.walk('output'):
    for filename in filenames:
        if filename.endswith('.csv'):
            obj = TablePattern(file_name= filename.removesuffix('.csv'))
            table_name = obj.table_name
            version_id = obj.version_id
            branch_id = obj.branch_id
            print(table_name, branch_id, version_id, filename)
            df = pd.read_csv(os.path.join(dirpath, filename), keep_default_na=False, low_memory=False)
            dfs.append({
                'table_name': table_name,
                'version_id': version_id,
                'branch_id': branch_id,
                'length': len(df),
                'df': df
            })
# 3m 50s

# %%
dfs = pd.DataFrame(dfs)

# %%
def _temp(row):
    row['df']['branch_id'] = row['branch_id']
dfs.apply(lambda x: _temp(x), axis=1)

# %%
# concat all df with same table_name and branch_id
dfs.groupby(['table_name', 'branch_id']).apply(lambda x: pd.concat(x['df'].tolist())).reset_index()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# d:\Workspace\Programming\Melbourne\PTV\test.ipynb Cell 8 line 2
#       <a href='vscode-notebook-cell:/d%3A/Workspace/Programming/Melbourne/PTV/test.ipynb#X31sZmlsZQ%3D%3D?line=0'>1</a> # concat all df with same table_name and branch_id
# ----> <a href='vscode-notebook-cell:/d%3A/Workspace/Programming/Melbourne/PTV/test.ipynb#X31sZmlsZQ%3D%3D?line=1'>2</a> dfs.groupby(['table_name', 'branch_id']).apply(lambda x: pd.concat(x['df'].tolist())).reset_index()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\groupby\groupby.py:1765, in GroupBy.apply(self, func, *args, **kwargs)
#    1763 with option_context("mode.chained_assignment", None):
#    1764     try:
# -> 1765         result = self._python_apply_general(f, self._selected_obj)
#    1766     except TypeError:
#    1767         # gh-20949
#    1768         # try again, with .apply acting as a filtering
#    (...)
#    1772         # fails on *some* columns, e.g. a numeric operation
#    1773         # on a string grouper column
#    1775         return self._python_apply_general(f, self._obj_with_exclusions)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\groupby\groupby.py:1818, in GroupBy._python_apply_general(self, f, data, not_indexed_same, is_transform, is_agg)
#    1815 if not_indexed_same is None:
#    1816     not_indexed_same = mutated
# -> 1818 return self._wrap_applied_output(
#    1819     data,
#    1820     values,
#    1821     not_indexed_same,
#    1822     is_transform,
#    1823 )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\groupby\generic.py:1594, in DataFrameGroupBy._wrap_applied_output(self, data, values, not_indexed_same, is_transform)
#    1592     return self.obj._constructor()
#    1593 elif isinstance(first_not_none, DataFrame):
# -> 1594     return self._concat_objects(
#    1595         values,
#    1596         not_indexed_same=not_indexed_same,
#    1597         is_transform=is_transform,
#    1598     )
#    1600 key_index = self.grouper.result_index if self.as_index else None
#    1602 if isinstance(first_not_none, (np.ndarray, Index)):
#    1603     # GH#1738: values is list of arrays of unequal lengths
#    1604     #  fall through to the outer else clause
#    1605     # TODO: sure this is right?  we used to do this
#    1606     #  after raising AttributeError above
#    1607     # GH 18930
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\groupby\groupby.py:1401, in GroupBy._concat_objects(self, values, not_indexed_same, is_transform)
#    1398     group_levels = self.grouper.levels
#    1399     group_names = self.grouper.names
# -> 1401     result = concat(
#    1402         values,
#    1403         axis=self.axis,
#    1404         keys=group_keys,
#    1405         levels=group_levels,
#    1406         names=group_names,
#    1407         sort=False,
#    1408     )
#    1409 else:
#    1410     # GH5610, returns a MI, with the first level being a
#    1411     # range index
#    1412     keys = list(range(len(values)))
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\reshape\concat.py:393, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     378     copy = False
#     380 op = _Concatenator(
#     381     objs,
#     382     axis=axis,
#    (...)
#     390     sort=sort,
#     391 )
# --> 393 return op.get_result()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\reshape\concat.py:667, in _Concatenator.get_result(self)
#     665 for obj in self.objs:
#     666     indexers = {}
# --> 667     for ax, new_labels in enumerate(self.new_axes):
#     668         # ::-1 to convert BlockManager ax to DataFrame ax
#     669         if ax == self.bm_axis:
#     670             # Suppress reindexing on concat axis
#     671             continue
#
# File properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\reshape\concat.py:698, in _Concatenator.new_axes(self)
#     695 @cache_readonly
#     696 def new_axes(self) -> list[Index]:
#     697     ndim = self._get_result_dim()
# --> 698     return [
#     699         self._get_concat_axis if i == self.bm_axis else self._get_comb_axis(i)
#     700         for i in range(ndim)
#     701     ]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\reshape\concat.py:699, in <listcomp>(.0)
#     695 @cache_readonly
#     696 def new_axes(self) -> list[Index]:
#     697     ndim = self._get_result_dim()
#     698     return [
# --> 699         self._get_concat_axis if i == self.bm_axis else self._get_comb_axis(i)
#     700         for i in range(ndim)
#     701     ]
#
# File properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\reshape\concat.py:758, in _Concatenator._get_concat_axis(self)
#     756     concat_axis = _concat_indexes(indexes)
#     757 else:
# --> 758     concat_axis = _make_concat_multiindex(
#     759         indexes, self.keys, self.levels, self.names
#     760     )
#     762 self._maybe_check_integrity(concat_axis)
#     764 return concat_axis
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\reshape\concat.py:832, in _make_concat_multiindex(indexes, keys, levels, names)
#     830     codes_list.extend(concat_index.codes)
#     831 else:
# --> 832     codes, categories = factorize_from_iterable(concat_index)
#     833     levels.append(categories)
#     834     codes_list.append(codes)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\arrays\categorical.py:2996, in factorize_from_iterable(values)
#    2991     codes = values.codes
#    2992 else:
#    2993     # The value of ordered is irrelevant since we don't use cat as such,
#    2994     # but only the resulting categories, the order of which is independent
#    2995     # from ordered. Set ordered to False as default. See GH #15457
# -> 2996     cat = Categorical(values, ordered=False)
#    2997     categories = cat.categories
#    2998     codes = cat.codes
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\arrays\categorical.py:449, in Categorical.__init__(self, values, categories, ordered, dtype, fastpath, copy)
#     447     values = sanitize_array(values, None)
#     448 try:
# --> 449     codes, categories = factorize(values, sort=True)
#     450 except TypeError as err:
#     451     codes, categories = factorize(values, sort=False)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\algorithms.py:763, in factorize(values, sort, use_na_sentinel, size_hint)
#     754 # Implementation notes: This method is responsible for 3 things
#     755 # 1.) coercing data to array-like (ndarray, Index, extension array)
#     756 # 2.) factorizing codes and uniques
#    (...)
#     760 # responsible only for factorization. All data coercion, sorting and boxing
#     761 # should happen here.
#     762 if isinstance(values, (ABCIndex, ABCSeries)):
# --> 763     return values.factorize(sort=sort, use_na_sentinel=use_na_sentinel)
#     765 values = _ensure_arraylike(values, func_name="factorize")
#     766 original = values
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\base.py:1195, in IndexOpsMixin.factorize(self, sort, use_na_sentinel)
#    1177 @doc(
#    1178     algorithms.factorize,
#    1179     values="",
#    (...)
#    1193     use_na_sentinel: bool = True,
#    1194 ) -> tuple[npt.NDArray[np.intp], Index]:
# -> 1195     codes, uniques = algorithms.factorize(
#    1196         self._values, sort=sort, use_na_sentinel=use_na_sentinel
#    1197     )
#    1198     if uniques.dtype == np.float16:
#    1199         uniques = uniques.astype(np.float32)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\algorithms.py:795, in factorize(values, sort, use_na_sentinel, size_hint)
#     792             # Don't modify (potentially user-provided) array
#     793             values = np.where(null_mask, na_value, values)
# --> 795     codes, uniques = factorize_array(
#     796         values,
#     797         use_na_sentinel=use_na_sentinel,
#     798         size_hint=size_hint,
#     799     )
#     801 if sort and len(uniques) > 0:
#     802     uniques, codes = safe_sort(
#     803         uniques,
#     804         codes,
#    (...)
#     807         verify=False,
#     808     )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\algorithms.py:595, in factorize_array(values, use_na_sentinel, size_hint, na_value, mask)
#     592 hash_klass, values = _get_hashtable_algo(values)
#     594 table = hash_klass(size_hint or len(values))
# --> 595 uniques, codes = table.factorize(
#     596     values,
#     597     na_sentinel=-1,
#     598     na_value=na_value,
#     599     mask=mask,
#     600     ignore_na=use_na_sentinel,
#     601 )
#     603 # re-cast e.g. i8->dt64/td64, uint8->bool
#     604 uniques = _reconstruct_data(uniques, original.dtype, original)
#
# File pandas\_libs\hashtable_class_helper.pxi:2976, in pandas._libs.hashtable.Int64HashTable.factorize()
#
# File pandas\_libs\hashtable_class_helper.pxi:2811, in pandas._libs.hashtable.Int64HashTable._unique()
#
# MemoryError: Unable to allocate 655. MiB for an array with shape (85800783,) and data type int64

# %%
for dfx in dfs:
    df : pd.DataFrame = dfx['df']
    if dfx['table_name'] == 'shapes':
        col_name = '__'.join(df.drop(['shape_id'], axis=1).columns)
        df = df.groupby(['shape_id']).apply(lambda x: x.drop(['shape_id'], axis=1).sort_values(by='shape_pt_sequence').to_dict('tight')['data']).to_frame(name=col_name).reset_index()
    elif dfx['table_name'] == 'stop_times':
        col_name = '__'.join(df.drop(['trip_id'], axis=1).columns)
        df = df.groupby(['trip_id']).apply(lambda x: x.drop(['trip_id'], axis=1).sort_values(by='stop_sequence').to_dict('tight')['data']).to_frame(name=col_name).reset_index()
        
# 1m 30s

# %%
dfs.sort(key=lambda x: x['length'], reverse=False)

# Connect to PostgreSQL
with psycopg2.connect(
    host=db_host,
    port=db_port,
    database=db_name,
    user=db_user,
    password=db_password
) as conn:
    
    with conn.cursor() as cursor:

        def insert_to_pg(df : pd.DataFrame, version_id, branch_id, table_name, debug_message=''):
            start_time = time.perf_counter()
            print('START', debug_message, start_time)
            # Count the number of rows in the PostgreSQL table where the version_id and branch_id match
            count_query = f"SELECT COUNT(*) FROM {table_name} WHERE version_id='{version_id}' AND branch_id='{branch_id}'"
            count = pd.read_sql(count_query, engine).iloc[0, 0]
            print('COUNT', table_name, version_id, branch_id, count, len(df))
            if count > 0 and count != len(df):
                # Delete the rows where the version_id and branch_id match
                delete_query = f"DELETE FROM {table_name} WHERE version_id='{version_id}' AND branch_id='{branch_id}'"
                cursor.execute(delete_query)
                conn.commit()
                print('DELETE', table_name, version_id, branch_id, count, len(df))
                # df.to_sql(table_name, engine, if_exists='append', index=False, chunksize=1000, method='multi')
                # print('INSERTED', table_name, version_id, branch_id, count, len(df))
            # elif count == 0:
                # df.to_sql(table_name, engine, if_exists='append', index=False, chunksize=1000, method='multi')
                # print('INSERTED', table_name, version_id, branch_id, count, len(df))

            end_time = time.perf_counter()
            print('END', debug_message, end_time)
            print('Time elapsed', end_time-start_time)

        tables = {}

        # with concurrent.futures.ThreadPoolExecutor() as executor:
        for counter, dfx in enumerate(dfs):
            table_name = dfx['table_name']
            version_id = dfx['version_id']
            branch_id = dfx['branch_id']
            dfx = dfx['df']
            if dfx is None:
                continue
            if table_name not in tables:
                tables[table_name] = []
            tables[table_name].append(dfx)
            # df.to_csv(f"output/{table_name}-{version_id}-{branch_id}.csv", index=False)
            debug_message = f"Loop {counter} / {len(dfs)}"
            # executor.submit(insert_to_pg, df, version_id, branch_id, table_name, debug_message)
            insert_to_pg(dfx, version_id, branch_id, table_name, debug_message)

        for table_name, df_list in tables.items():
            pd.concat(df_list).to_csv(f"output_all/{table_name}.csv", index=False)
